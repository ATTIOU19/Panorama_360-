# %%
import sys
sys.path.insert(0, r"C:\Users\hp\Desktop\Projet_WTM\src")

import importlib, stitching_pipeline
importlib.reload(stitching_pipeline)
from stitching_pipeline import run_pipeline

run_pipeline(
    input_dir=r"C:\Users\hp\Desktop\Projet_WTM\data\raw\tajm",
    output_path=r"C:\Users\hp\Desktop\Projet_WTM\outputs\panoramas\panorama_final.jpg",
    mode="auto",
    output_width=3000,
    output_height=1200,
)
# Out:
# [10:04:43] INFO — === Démarrage pipeline de stitching — mode AUTO ===
# [10:04:43] INFO — Étape 1a — 8 images chargées depuis C:\Users\hp\Desktop\Projet_WTM\tajm
# [10:04:43] INFO — Étape 1b — Prétraitement appliqué (resize max=1600px, CLAHE=False)
# [10:04:43] INFO — Mode AUTO — lancement de cv2.Stitcher sur 8 images...
# [10:04:51] INFO — Étape 5 — Reprojection équirectangulaire : 3000x1200 (ratio 2:1)
# [10:04:51] INFO — Étape 6 — Panorama exporté : C:\Users\hp\Desktop\Projet_WTM\panorama_final.jpg (389 Ko)
# [10:04:51] INFO — QC — Score de continuité de jonction 0°/360° : 0.712 (1.0 = parfait)
# [10:04:51] INFO — === Pipeline terminé avec succès : C:\Users\hp\Desktop\Projet_WTM\panorama_final.jpg ===
# True
